# %% [markdown]
# <h3> Mock Interview Python Screening test </h3>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
dataframe = pd.read_csv("adult_census_data.csv", sep=r', ')

# %%
dataframe.columns
# Out:
# Index(['39', 'State-gov', '77516', 'Bachelors', '13', 'Never-married',
#        'Adm-clerical', 'Not-in-family', 'White', 'Male', '2174', '0', '40',
#        'United-States', '<=50K'],
#       dtype='object')

# %% [markdown]
# <b> Q1. After importing the adult_census_data.csv file, please filter this to include only the following criteria: </b>
# <p>
#
# <li> State-Gov</li>
# <li> Bachelors </li>
# <li> Never-Married </li>
# <li> Adm-Clerical </li>
# <li> Not-in-familiy </li>
# <li> White </li>
# <li> Male </li>
# <li> United States </li>
# <li> <=50K </li>
#
# <b> Feel free to any method to complete this tasks. However, we recommend you use either list filtering [], or .loc to complete this task.</b>

# %% [markdown]
# <b> Put your code below </b>

# %%
df = dataframe[['State-gov','Bachelors','Never-married','Adm-clerical', 'Not-in-family', 'White', 'Male','United-States','<=50K']]
df
# Out:
#               State-gov   Bachelors       Never-married       Adm-clerical  \
# 0      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 1               Private     HS-grad            Divorced  Handlers-cleaners
# 2               Private        11th  Married-civ-spouse  Handlers-cleaners
# 3               Private   Bachelors  Married-civ-spouse     Prof-specialty
# 4               Private     Masters  Married-civ-spouse    Exec-managerial
# ...                 ...         ...                 ...                ...
# 32555           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32556           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32557           Private     HS-grad             Widowed       Adm-clerical
# 32558           Private     HS-grad       Never-married       Adm-clerical
# 32559      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#        Not-in-family  White    Male  United-States  <=50K
# ...

# %% [markdown]
# <b> Currently, the dataframe you are using has the following column names: </b>
#
# [' State-gov', ' Bachelors', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' United-States', ' <=50K']
#
#
# <b> Q2. Please re-name all the newly filtered columns in the pandas DataFrame to the following: </b>
#
# Employment Type, Degree Status, Marriage-Status, Job-Role, Family-Role, Ethnicity, Gender, Country, Earnings
#
# E.g. State-Gov becomes Employment Type, Bachelors becomes Degree Status, etc.

# %% [markdown]
# <b> Put your code below </b>

# %%
census = df.rename(columns={'State-gov': 'Employment Type', 'Bachelors': 'Degree Status', 
                  'Never-married': 'Marriage-Status', 'Adm-clerical': 'Job-Role',
                  'Not-in-family': 'Family-Role', 'White': 'Ethnicity',
                  'Male': 'Gender', 'United-States': 'Country',
                  '<=50K':'Earnings'})
census
# Out:
#         Employment Type Degree Status     Marriage-Status           Job-Role  \
# 0      Self-emp-not-inc     Bachelors  Married-civ-spouse    Exec-managerial
# 1               Private       HS-grad            Divorced  Handlers-cleaners
# 2               Private          11th  Married-civ-spouse  Handlers-cleaners
# 3               Private     Bachelors  Married-civ-spouse     Prof-specialty
# 4               Private       Masters  Married-civ-spouse    Exec-managerial
# ...                 ...           ...                 ...                ...
# 32555           Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32556           Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32557           Private       HS-grad             Widowed       Adm-clerical
# 32558           Private       HS-grad       Never-married       Adm-clerical
# 32559      Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
# ...

# %% [markdown]
# <b> Q3. The Job Role Columns holds the job information for each individual in this census snapshot. Using this column, create a Bar Chart that shows the count of 'Unique' Jobs per Job Group in the "Job-Role" Column in ascending order, as per the provided image below </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
condition = census.groupby(["Job-Role"]).agg(count = ("Job-Role","count"))
job = condition.sort_values("count", ascending=False)
job.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Job-Role'>

# %% [markdown]
# <b> Q4. Please create two bar plots as per below that show:
#
#     1) The number of individuals who have a High School Graduate Diploma AND earn <=50K in the United States
#     2) The number of individuals who have a High School Graduate Diploma AND earn >50K in the United States
#
# Please note you will be looking specifically at the *Job Role* column

# %% [markdown]
# <b> Put Your Code Below </b>

# %%
less_50 = census[(census["Degree Status"] == 'HS-grad') & (census["Earnings"] == '<=50K')]
count_less_50 = less_50.groupby(["Job-Role"]).agg(count = ("Job-Role","count"))
less = count_less_50.sort_values("count", ascending=False)
less.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Job-Role'>

# %%
more_50 = census[(census["Degree Status"] == 'HS-grad') & (census["Earnings"] == '>50K')]
count_more_50 = more_50.groupby(["Job-Role"]).agg(count = ("Job-Role","count"))
more = count_more_50.sort_values("count", ascending=False)
more.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Job-Role'>

# %% [markdown]
# <H2> Challenge Question </H2>
#
# <b> Q5. Which Job Role has the highest <i> proportion </i> of individuals who earn >50K? </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
proportions = census[(census["Earnings"] == '>50K')]
test = proportions.groupby(["Job-Role"]).agg(count = ("Job-Role","count")).reset_index()
test[all] = test
# Out:
#              Job-Role  count
# 0                   ?    191
# 1        Adm-clerical    507
# 2        Armed-Forces      1
# 3        Craft-repair    929
# 4     Exec-managerial   1968
# 5     Farming-fishing    115
# 6   Handlers-cleaners     86
# 7   Machine-op-inspct    250
# 8       Other-service    137
# 9     Priv-house-serv      1
# 10     Prof-specialty   1859
# 11    Protective-serv    211
# 12              Sales    983
# 13       Tech-support    283
# 14   Transport-moving    320

# %%
test['percent'] = (test['count'] / 
                  test['count'].sum()) * 100
test_sort = test.sort_values('percent')
test_sort
# Out:
#              Job-Role  count    percent
# 2        Armed-Forces      1   0.012753
# 9     Priv-house-serv      1   0.012753
# 6   Handlers-cleaners     86   1.096799
# 5     Farming-fishing    115   1.466650
# 8       Other-service    137   1.747226
# 0                   ?    191   2.435914
# 11    Protective-serv    211   2.690983
# 7   Machine-op-inspct    250   3.188369
# 13       Tech-support    283   3.609234
# 14   Transport-moving    320   4.081112
# 1        Adm-clerical    507   6.466012
# 3        Craft-repair    929  11.847979
# 12              Sales    983  12.536666
# 10     Prof-specialty   1859  23.708711
# 4     Exec-managerial   1968  25.098839
